# %% [markdown]
# # Data Science FX project : Daniel Barclay 2019 - 2020
# # Federal Reserve Economic Data (FRED) FX Analysis Project
#
# I wanted to do some exploratory analysis of foreign exchange rate time series data.
#
# I looked at the [Federal Reserve Economic Data (FRED) website](https://fred.stlouisfed.org).
#
# I accessed this through pandas in Python using the data reader package, which loads the data into a data frame.
#
# The log return diagrams show the rate of change of each currency day on day.
#
# Each analysis gives further insight about the data. For instance, the swiss franc showed an opposite trend to most of the currencies.
#
# Next I created a scatter matrix
#
# The scatter matrix has pair plots of one currency against another in a square grid. The diagonal plots however show the histogram or probability density of a single exchange rate. It estimates the rate of occurrence of each value.
#
# An anomaly appears to be the Danish Kroner as it appears to be almost perfectly correlated with the euro (appearing as a straight diagonal line in the pair plot).
#
# Then I showed a heatmap plot of correlations which essentially show how each exchange rate is correlated. We can see that the euro-USD exchange rate is fairly strongly correlated with the GBP-USD (deep orange).
#
# This is useful for investors to diversify and spread risk. Investors should choose exchange rates that are poorly correlated or anti-correlated (blue in this diagram).

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas_datareader.data as web
import pandas as pd
import datetime as dt
start = dt.datetime(2007,1,1)
end = dt.datetime(2019,12,31)
fx_symbols = ["DEXUSUK", "DEXUSEU", "DEXJPUS", "DEXCAUS", "DEXDNUS", "DEXNOUS","DEXSZUS","DEXSDUS","DEXCHUS"]
FX = web.DataReader(fx_symbols, 'fred', start,end)

# %%
fred2iso = {'US':'USD', 'UK':'GBP', 'EU':'EUR', 'JP':'JPY', 'CA':'CAD', 'DN':'DKK', 'NO':'NOK', 'SZ':'CHF', 'SD':'SEK', 'CH':'CNY'}

# %%
fred2iso['UK']
# Out:
# 'GBP'

# %%
cols = [fred2iso[c[5:]] + "-" + fred2iso[c[3:5]] for c in FX.columns]

# %%
FX.columns = cols
FX.columns
# Out:
# Index(['GBP-USD', 'EUR-USD', 'USD-JPY', 'USD-CAD', 'USD-DKK', 'USD-NOK',
#        'USD-CHF', 'USD-SEK', 'USD-CNY'],
#       dtype='object')

# %% [markdown]
# I had to invert some data because some exchange rates were US dollars to other currencies, while other exchange rates were other currencies to US dollars, so I had to make them all the same by taking reciprocals as I wanted all exchange rates expressed as other currencies to US dollars. I removed the missing data using the pandas dropna function.

# %%
FX['USD-GBP'] = 1/FX['GBP-USD']
FX['USD-EUR'] = 1/FX['EUR-USD']

# %%
FX.drop(['EUR-USD','GBP-USD'], axis=1, inplace = True)
FX.dropna(inplace = True)

# %%
FX
# Out:
#             USD-JPY  USD-CAD  USD-DKK  USD-NOK  USD-CHF  USD-SEK  USD-CNY  \
# DATE
# 2007-01-02   118.83   1.1647   5.6119   6.1809   1.2125   6.7818   7.8051
# 2007-01-03   119.58   1.1699   5.6589   6.2598   1.2263   6.8539   7.8051
# 2007-01-04   119.28   1.1766   5.6913   6.3229   1.2314   6.9335   7.8090
# 2007-01-05   118.77   1.1753   5.7302   6.3513   1.2366   6.9744   7.8047
# 2007-01-08   118.49   1.1777   5.7207   6.3592   1.2357   6.9972   7.8127
# 2007-01-09   119.45   1.1782   5.7359   6.3536   1.2417   7.0232   7.8055
# 2007-01-10   119.52   1.1770   5.7581   6.4363   1.2459   7.0542   7.8075
# 2007-01-11   120.49   1.1761   5.7756   6.4728   1.2482   7.0829   7.7945
# 2020-01-10  0.765697  0.899361
# 2020-01-13  0.770238  0.897827
# 2020-01-14  0.768167  0.898473
# 2020-01-15  0.767460  0.896057
# 2020-01-16  0.764760  0.898392
# 2020-01-17  0.767519  0.901469
# 2020-01-21  0.766460  0.901226
# 2020-01-22  0.761267  0.902120
# 2020-01-23  0.763126  0.905715
# 2020-01-24  0.765052  0.906947
#
# [3276 rows x 9 columns]

# %% [markdown]
# I plotted FX rate value to USD against date.
#
# I looked at 6 currencies, looking at data points for each between 2007 – 2011, then I plotted all the currencies over time using Matplotlib
#
# At this point I decided to expand the data to 2007 – 2019 and added 3 more currencies, and the program made the change automatically. I could also easily add other currencies.
#
# \*Because Japanese Yen has a higher exchange rate (approximately 100), it makes fluctuations in the currencies with smaller exchange rates very hard to see if you don’t normalise it.

# %%
FX.plot()

# %% [markdown]
# Then I looked at correlations between each of the different FX rates. The bottom range of the diagram shows how much fluctuation there is in a specific time region for each currency against USD. I used a different colour for each currency.

# %%
FX.plot(subplots=True,figsize=(15,11),layout=(3, 3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C687A96E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687ACA438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687AF1860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C687B18CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687B4C160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687B725C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C687B9AA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687BC3EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687BC3EF0>]],
#       dtype=object)

# %% [markdown]
# To show log returns, which is a ratio of 2 consecutive samples.
#
# I found $\log \left(\frac{\text{today}}{\text{previous day}}\right)$, or $\log (\text{today})- \log(\text{previous day})$.
#
# Taking logs turns it into a proportional scaling, in which 0=unchanged, 0.1 = 10% increase, 0.2= 20% increase etc. Logs are the commonly used convention.
#
# The log return diagrams show the rate of change of each currency day on day.

# %%
from numpy import log

# %%
FX_returns = log(FX/FX.shift(1))

# %%
# Now we get the log-returns (one-day)
FX_returns.plot(subplots=True,figsize=(15,11),layout=(3, 3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C68813C940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C6881F2F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687DD2358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C687DFB7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687E22C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687E530B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C687E7B518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687EA49B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C687EA49E8>]],
#       dtype=object)

# %% [markdown]
# Plot of CHF-GBP exchange rate over time

# %%
Data_frame = FX['USD-CHF']/FX['USD-GBP']
Data_frame.plot()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(FX.loc[:,"USD-JPY":"USD-EUR"], diagonal = "kde",figsize = (20,16))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# %% [markdown]
# I computed a correlation matrix based on the returns which shows how the currencies behave relative to each other. A positive value indicates tracking (+1 = perfectly correlated, 0= no correlation, and a negative value = going in the other direction).

# %%
FX.corr()
# Out:
#           USD-JPY   USD-CAD   USD-DKK   USD-NOK   USD-CHF   USD-SEK   USD-CNY  \
# USD-JPY  1.000000  0.652845  0.500182  0.581174  0.338163  0.497933  0.301814
# USD-CAD  0.652845  1.000000  0.856415  0.959561  0.073878  0.926845  0.100614
# USD-DKK  0.500182  0.856415  1.000000  0.931380 -0.124880  0.882166 -0.098303
# USD-NOK  0.581174  0.959561  0.931380  1.000000 -0.053960  0.956136  0.019945
# USD-CHF  0.338163  0.073878 -0.124880 -0.053960  1.000000  0.070656  0.813837
# USD-SEK  0.497933  0.926845  0.882166  0.956136  0.070656  1.000000  0.121451
# USD-CNY  0.301814  0.100614 -0.098303  0.019945  0.813837  0.121451  1.000000
# USD-GBP  0.135194  0.742910  0.802862  0.828014 -0.292148  0.838689 -0.184958
# USD-EUR  0.497596  0.855304  0.999906  0.930258 -0.123365  0.881316 -0.097666
#
#           USD-GBP   USD-EUR
# USD-JPY  0.135194  0.497596
# USD-CAD  0.742910  0.855304
# USD-DKK  0.802862  0.999906
# USD-NOK  0.828014  0.930258
# USD-CHF -0.292148 -0.123365
# USD-SEK  0.838689  0.881316
# USD-CNY -0.184958 -0.097666
# USD-GBP  1.000000  0.803867
# USD-EUR  0.803867  1.000000

# %%
sns.heatmap(FX.corr(),cmap='coolwarm',vmin=-1,vmax=1)

# %%
x=FX.corr()
x.values
# Out:
# array([[ 1.        ,  0.6528447 ,  0.50018211,  0.58117376,  0.33816256,
#          0.49793313,  0.30181448,  0.13519396,  0.49759555],
#        [ 0.6528447 ,  1.        ,  0.8564148 ,  0.95956147,  0.07387801,
#          0.92684455,  0.1006144 ,  0.74290982,  0.85530438],
#        [ 0.50018211,  0.8564148 ,  1.        ,  0.93137982, -0.1248797 ,
#          0.88216598, -0.09830331,  0.80286222,  0.99990609],
#        [ 0.58117376,  0.95956147,  0.93137982,  1.        , -0.05396025,
#          0.9561361 ,  0.01994546,  0.82801392,  0.93025807],
#        [ 0.33816256,  0.07387801, -0.1248797 , -0.05396025,  1.        ,
#          0.07065592,  0.8138365 , -0.2921478 , -0.12336476],
#        [ 0.49793313,  0.92684455,  0.88216598,  0.9561361 ,  0.07065592,
#          1.        ,  0.12145135,  0.83868894,  0.88131634],
#        [ 0.30181448,  0.1006144 , -0.09830331,  0.01994546,  0.8138365 ,
#          0.12145135,  1.        , -0.18495805, -0.09766575],
#        [ 0.13519396,  0.74290982,  0.80286222,  0.82801392, -0.2921478 ,
#          0.83868894, -0.18495805,  1.        ,  0.80386716],
#        [ 0.49759555,  0.85530438,  0.99990609,  0.93025807, -0.12336476,
#          0.88131634, -0.09766575,  0.80386716,  1.        ]])

# %%
#print(np.linalg.eig(x)[0])

# %%
fx=FX.rolling(100).mean()

# %%
fx.plot(subplots=True,figsize=(15,11),layout=(3, 3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C68CB5DB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C68CAE8FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C68AFD4400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C68AFD8860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C68AF89CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C68AF47160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C68C3AE5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C68C3C2A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C68C3C2A90>]],
#       dtype=object)

# %%
#fig, axs = plt.subplots(2, 2)
#axs[0,0].plot(FX)
#plt.plot(FX,subplots=True)
#plt.plot(fx)
#FX.plot()
#fx.plot(subplots=True,figsize=(15,11),layout=(3, 3))

# %% [markdown]
# # Extending the analysis to energy markets

# %%
import quandl
import matplotlib.pyplot as plt
import numpy as np
import pandas_datareader.data as web
import pandas as pd
import datetime as dt
import seaborn as sns

# %%
quandl.ApiConfig.api_key = '4nrCzYAzzubd7HcLYyxb'

# %%
df = quandl.get(["EIA/PET_RWTC_D","FRED/DCOILBRENTEU","EIA/NG_RNGWHHD_D","EIA/PET_EER_EPD2F_PF4_Y35NY_DPG_D","EIA/PET_EER_EPMRU_PF4_Y35NY_DPG_D","EIA/PET_EER_EPD2DXL0_PF4_Y35NY_DPG_D","EIA/PET_EER_EPJK_PF4_RGC_DPG_D"])

# %%
df.columns = ["WTI","Brent","Natural gas","Heating oil","Gasoline","Diesel","Jet"]

# %%
df.columns
# Out:
# Index(['WTI', 'Brent', 'Natural gas', 'Heating oil', 'Gasoline', 'Diesel',
#        'Jet'],
#       dtype='object')

# %%
df
# Out:
#               WTI  Brent  Natural gas  Heating oil  Gasoline  Diesel    Jet
# Date
# 1986-01-02  25.56    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-03  26.00    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-06  26.53    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-07  25.85    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-08  25.87    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-09  26.03    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-10  25.65    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-13  25.08    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-14  24.97    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-15  25.18    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-16  23.98    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-17  23.63    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-20  21.33    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-21  20.61    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-22  20.25    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-23  19.93    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-24  19.45    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-27  20.87    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-28  19.45    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-29  19.61    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-30  19.58    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-01-31  18.95    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-02-03  17.42    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-02-04  15.58    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-02-05  16.28    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-02-06  16.60    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-02-07  17.70    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-02-10  16.78    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-02-11  16.28    NaN          NaN          NaN       NaN     NaN    NaN
# 1986-02-12  15.74    NaN          NaN          NaN       NaN     NaN    NaN
# ...           ...    ...          ...          ...       ...     ...    ...
# 2019-12-24  61.17  69.26         2.11        2.017     1.768   2.034  1.961
# 2019-12-25  61.17    NaN         2.11          NaN       NaN     NaN    NaN
# 2019-12-26  61.72    NaN         2.09        2.030     1.791   2.048  1.977
# 2019-12-27  61.76  68.91         1.75        2.028     1.785   2.046  1.980
# 2019-12-30  61.66  68.30         2.06        2.017     1.766   2.034  1.965
# 2019-12-31  61.14  67.77         2.09        2.004     1.738   2.022  1.942
# 2020-01-01  61.14    NaN         2.09        2.004     1.738   2.022  1.942
# 2020-01-02  61.17  67.05         2.05        2.002     1.744   2.019  1.934
# 2020-01-03  63.00  69.08         2.06        2.039     1.792   2.054  1.972
# 2020-01-06  63.27  70.25         2.10        2.004     1.783   2.019  1.941
# 2020-01-07  62.70  68.74         2.17        2.009     1.758   2.024  1.949
# 2020-01-08  59.65  67.31         2.09        1.952     1.698   1.967  1.892
# 2020-01-09  59.56  66.58         2.09        1.934     1.696   1.946  1.874
# 2020-01-10  59.02  66.77         2.05        1.916     1.698   1.929  1.856
# 2020-01-13  58.17  64.14         2.03        1.881     1.698   1.894  1.821
# 2020-01-14  58.34  64.45         2.15        1.887     1.695   1.912  1.822
# 2020-01-15  57.86  63.29         2.01        1.857     1.686   1.882  1.792
# 2020-01-16  58.52  64.63         2.06        1.839     1.703   1.859  1.774
# 2020-01-17  58.55  64.05         2.07        1.833     1.686   1.860  1.773
# 2020-01-20    NaN  64.63          NaN        1.833     1.686   1.860  1.773
# 2020-01-21  58.25  63.66         1.98        1.796     1.677   1.824  1.736
# 2020-01-22  56.76  62.11         1.89        1.767     1.618   1.794  1.711
# 2020-01-23  55.51  61.26         1.95        1.759     1.603   1.787  1.702
# 2020-01-24  54.09  59.34         1.91        1.709     1.559   1.729  1.665
# 2020-01-27  53.09  58.54         2.03        1.641     1.517   1.661  1.598
# 2020-01-28  53.33    NaN         1.96        1.688     1.543   1.708  1.641
# 2020-01-29  53.29    NaN         1.93        1.667     1.571   1.677  1.620
# 2020-01-30  52.19    NaN         1.94        1.634     1.562   1.644  1.584
# 2020-01-31  51.58    NaN         1.91        1.595     1.534   1.620  1.504
# 2020-02-03  50.06    NaN         1.90        1.540     1.505   1.570  1.450
#
# [8742 rows x 7 columns]

# %%
df.plot()

# %%
df.plot(subplots=True,figsize=(15,11),layout=(3, 3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF631B3EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF6363C470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF636228D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF632C4CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF6351A198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF635455F8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF62EF0A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF62D18EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF62D18F28>]],
#       dtype=object)

# %%
df_returns = np.log(df/df.shift(1))

# %%
df_returns.plot(subplots=True,figsize=(15,11),layout=(3, 3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF6366E828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF6283B3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF628637F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF6288BC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF6296B0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF62992550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF629BC9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF629E3E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF629E3E80>]],
#       dtype=object)

# %%
df.corr()
# Out:
#                   WTI     Brent  Natural gas  Heating oil  Gasoline    Diesel  \
# WTI          1.000000  0.990128     0.344994     0.988069  0.983145  0.958897
# Brent        0.990128  1.000000     0.252316     0.994760  0.990325  0.983102
# Natural gas  0.344994  0.252316     1.000000     0.287033  0.252957  0.386228
# Heating oil  0.988069  0.994760     0.287033     1.000000  0.987444  0.996522
# Gasoline     0.983145  0.990325     0.252957     0.987444  1.000000  0.960997
# Diesel       0.958897  0.983102     0.386228     0.996522  0.960997  1.000000
# Jet          0.987941  0.992081     0.316289     0.996336  0.986771  0.993204
#
#                   Jet
# WTI          0.987941
# Brent        0.992081
# Natural gas  0.316289
# Heating oil  0.996336
# Gasoline     0.986771
# Diesel       0.993204
# Jet          1.000000

# %%
sns.heatmap(df.corr(),cmap='coolwarm',vmin=-1,vmax=1)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df.loc[:,"WTI":"Jet"], diagonal = "kde",figsize = (20,16))
plt.tight_layout()
plt.show()

# %%
df_rolling=df.rolling(50).mean()

# %%
df_rolling.plot(subplots=True,figsize=(15,11),layout=(3, 3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF66AAED30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF639876A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF63975AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF662D3F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF6392E3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF6391E828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF639C8C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF6634A160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF6634A198>]],
#       dtype=object)
